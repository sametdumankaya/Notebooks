# %% [markdown]
# ### Import required packages and read the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
matplotlib.rcParams['figure.figsize'] = (15, 5)

# %%
df_customers = pd.read_csv('olist_customers_dataset.csv')
df_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
df_geolocation = pd.read_csv('olist_geolocation_dataset.csv')
df_geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
df_order_items = pd.read_csv('olist_order_items_dataset.csv')
df_order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
df_order_payments = pd.read_csv('olist_order_payments_dataset.csv')
df_order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
df_order_reviews = pd.read_csv('olist_order_reviews_dataset.csv')
df_order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
df_orders = pd.read_csv('olist_orders_dataset.csv')
df_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
df_products = pd.read_csv('olist_products_dataset.csv')
df_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
df_sellers = pd.read_csv('olist_sellers_dataset.csv')
df_sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
df_prodct_category_translation = pd.read_csv('product_category_name_translation.csv')
df_prodct_category_translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# ### If there are any duplicate orders, we should have only one of them

# %%
df_order_payments = df_order_payments.drop_duplicates('order_id', False)

# %% [markdown]
# ### Merge different DataFrames into one big DataFrame

# %%
df = pd.merge(df_orders, df_order_payments, on="order_id")
df = df.merge(df_customers, on="customer_id")
df = df.merge(df_order_items, on="order_id")
df = df.merge(df_products, on="product_id")
df = df.merge(df_prodct_category_translation, on="product_category_name")
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 1  40c5e18f7d112b59b3e5113a59a905b3  67407057a7d5ee17d1cd09523f484d13
# 2  86674ccaee19790309333210917b2c7d  1b338293f35549b5e480b9a3d7bbf3cd
# 3  f913d229653fdd809c249ed98ab6b754  e1365d7b227b247b6bc0931771885eaf
# 4  9b85bbefeeacfebc3ff603d20511734f  7f4f07b97783e894fccff9d72e0988b3
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 1    delivered      2018-06-11 10:25:52  2018-06-11 10:58:32
# 2    delivered      2018-08-09 11:37:35  2018-08-09 14:35:19
# 3    delivered      2018-04-30 02:18:32  2018-04-30 03:00:14
# 4    delivered      2017-11-27 10:32:51  2017-11-27 11:14:36
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2018-07-26 14:31:00           2018-08-07 15:27:45
# 1          2018-06-14 13:03:00           2018-06-19 00:31:13
# 2          2018-08-10 14:34:00           2018-08-14 18:51:47
# 3          2018-04-30 13:54:00           2018-05-08 17:53:51
# 4          2017-11-29 15:16:47           2017-12-07 19:48:32
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0           2018-08-13 00:00:00                   1       boleto
# 1           2018-07-16 00:00:00                   1  credit_card
# 2           2018-08-22 00:00:00                   1  credit_card
# 3           2018-05-24 00:00:00                   1  credit_card
# 4           2017-12-20 00:00:00                   1  credit_card
#
#    payment_installments  payment_value                customer_unique_id  \
# 0                     1         141.46  af07308b275d755c9edb36a90c618231
# 1                     3         128.68  7cfba6e55439cae3fd2479d62fafe67f
# 2                     5         135.82  8b8028d453a01986b48c4271cc341475
# 3                     4         137.45  66c70ed7726abccfbee61a9a39de15c5
# 4                     3         126.11  293c9db44b6588c4e52fbef455fccde8
#
#    customer_zip_code_prefix   customer_city customer_state  order_item_id  \
# 0                     47813       barreiras             BA              1
# 1                     22240  rio de janeiro             RJ              1
# 2                     14500       ituverava             SP              1
# 3                     90050    porto alegre             RS              1
# 4                     88085   florianopolis             SC              1
#
#                          product_id                         seller_id  \
# 0  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 1  595fac2a385ac33a80bd5114aec74eb8  ef0ace09169ac090589d85746e3e036f
# 2  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 3  595fac2a385ac33a80bd5114aec74eb8  ef0ace09169ac090589d85746e3e036f
# 4  595fac2a385ac33a80bd5114aec74eb8  ef0ace09169ac090589d85746e3e036f
#
#    shipping_limit_date  price  freight_value product_category_name  \
# 0  2018-07-30 03:24:27  118.7          22.76            perfumaria
# 1  2018-06-15 10:58:32  119.9           8.78            perfumaria
# 2  2018-08-13 14:31:29  116.9          18.92            perfumaria
# 3  2018-05-07 02:31:13  119.9          17.55            perfumaria
# 4  2017-12-01 11:14:36  109.9          16.21            perfumaria
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 29.0                       178.0                 1.0
# 1                 29.0                       178.0                 1.0
# 2                 29.0                       178.0                 1.0
# 3                 29.0                       178.0                 1.0
# 4                 29.0                       178.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             400.0               19.0               13.0              19.0
# 1             400.0               19.0               13.0              19.0
# 2             400.0               19.0               13.0              19.0
# 3             400.0               19.0               13.0              19.0
# 4             400.0               19.0               13.0              19.0
#
#   product_category_name_english
# 0                     perfumery
# 1                     perfumery
# 2                     perfumery
# 3                     perfumery
# 4                     perfumery

# %% [markdown]
# ### Geolocation information is important in terms of delivery time. Farther customer means longer delivery time. Additionally, calculate the mean of the lat and lng values based on state

# %%
df['customer_state'] = df['customer_state'].apply(lambda x : x.lower())
df['customer_city'] = df['customer_city'].apply(lambda x : x.lower())
geo_state = df_geolocation.groupby('geolocation_state')['geolocation_lat','geolocation_lng'].mean().reset_index()
geo_state['geolocation_state'] = geo_state['geolocation_state'].apply(lambda x : x.lower())
geo_city = df_geolocation.groupby('geolocation_city')['geolocation_lat','geolocation_lng'].mean().reset_index()
geo_city['geolocation_city'] = geo_city['geolocation_city'].apply(lambda x : x.lower())
geo_city.rename(columns={'geolocation_lat': 'mean_lat','geolocation_lng':'mean_lng'}, inplace=True)
df = pd.merge(df, geo_state, how='left', left_on='customer_state',right_on='geolocation_state')
df = pd.merge(df, geo_city,how='left',left_on='customer_city',right_on='geolocation_city')
df.head()
# Out:
# c:\users\samet\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\samet\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """
#                            order_id                       customer_id  \
# 0  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 1  40c5e18f7d112b59b3e5113a59a905b3  67407057a7d5ee17d1cd09523f484d13
# 2  86674ccaee19790309333210917b2c7d  1b338293f35549b5e480b9a3d7bbf3cd
# 3  f913d229653fdd809c249ed98ab6b754  e1365d7b227b247b6bc0931771885eaf
# 4  9b85bbefeeacfebc3ff603d20511734f  7f4f07b97783e894fccff9d72e0988b3
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 1    delivered      2018-06-11 10:25:52  2018-06-11 10:58:32
# 2    delivered      2018-08-09 11:37:35  2018-08-09 14:35:19
# 3    delivered      2018-04-30 02:18:32  2018-04-30 03:00:14
# 4    delivered      2017-11-27 10:32:51  2017-11-27 11:14:36
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2018-07-26 14:31:00           2018-08-07 15:27:45
# 1          2018-06-14 13:03:00           2018-06-19 00:31:13
# 2          2018-08-10 14:34:00           2018-08-14 18:51:47
# 3          2018-04-30 13:54:00           2018-05-08 17:53:51
# 4          2017-11-29 15:16:47           2017-12-07 19:48:32
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0           2018-08-13 00:00:00                   1       boleto
# 1           2018-07-16 00:00:00                   1  credit_card
# 2           2018-08-22 00:00:00                   1  credit_card
# 3           2018-05-24 00:00:00                   1  credit_card
# 4           2017-12-20 00:00:00                   1  credit_card
#
#    payment_installments  payment_value                customer_unique_id  \
# 0                     1         141.46  af07308b275d755c9edb36a90c618231
# 1                     3         128.68  7cfba6e55439cae3fd2479d62fafe67f
# 2                     5         135.82  8b8028d453a01986b48c4271cc341475
# 3                     4         137.45  66c70ed7726abccfbee61a9a39de15c5
# 4                     3         126.11  293c9db44b6588c4e52fbef455fccde8
#
#    customer_zip_code_prefix   customer_city customer_state  order_item_id  \
# 0                     47813       barreiras             ba              1
# 1                     22240  rio de janeiro             rj              1
# 2                     14500       ituverava             sp              1
# 3                     90050    porto alegre             rs              1
# 4                     88085   florianopolis             sc              1
#
#                          product_id                         seller_id  \
# 0  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 1  595fac2a385ac33a80bd5114aec74eb8  ef0ace09169ac090589d85746e3e036f
# 2  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 3  595fac2a385ac33a80bd5114aec74eb8  ef0ace09169ac090589d85746e3e036f
# 4  595fac2a385ac33a80bd5114aec74eb8  ef0ace09169ac090589d85746e3e036f
#
#    shipping_limit_date  price  freight_value product_category_name  \
# 0  2018-07-30 03:24:27  118.7          22.76            perfumaria
# 1  2018-06-15 10:58:32  119.9           8.78            perfumaria
# 2  2018-08-13 14:31:29  116.9          18.92            perfumaria
# 3  2018-05-07 02:31:13  119.9          17.55            perfumaria
# 4  2017-12-01 11:14:36  109.9          16.21            perfumaria
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 29.0                       178.0                 1.0
# 1                 29.0                       178.0                 1.0
# 2                 29.0                       178.0                 1.0
# 3                 29.0                       178.0                 1.0
# 4                 29.0                       178.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             400.0               19.0               13.0              19.0
# 1             400.0               19.0               13.0              19.0
# 2             400.0               19.0               13.0              19.0
# 3             400.0               19.0               13.0              19.0
# 4             400.0               19.0               13.0              19.0
#
#   product_category_name_english geolocation_state  geolocation_lat  \
# 0                     perfumery                ba       -13.049361
# 1                     perfumery                rj       -22.743477
# 2                     perfumery                sp       -23.155308
# 3                     perfumery                rs       -29.679191
# 4                     perfumery                sc       -27.222486
#
#    geolocation_lng geolocation_city   mean_lat   mean_lng
# 0       -39.560649        barreiras -12.148291 -44.967260
# 1       -43.155540   rio de janeiro -22.914910 -43.312883
# 2       -47.084074        ituverava -20.331414 -47.789388
# 3       -52.032652     porto alegre -30.049252 -51.188582
# 4       -49.617937    florianopolis -27.576836 -48.517952

# %% [markdown]
# ### Since only a very small piece of data is missing, we can drop the missing values safely

# %%
df.shape
# Out:
# (107792, 37)

# %%
df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                  14
# order_delivered_carrier_date     1124
# order_delivered_customer_date    2326
# order_estimated_delivery_date       0
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# product_category_name               0
# product_name_lenght                 0
# product_description_lenght          0
# product_photos_qty                  0
# product_weight_g                    1
# product_length_cm                   1
# product_height_cm                   1
# product_width_cm                    1
# product_category_name_english       0
# geolocation_state                   0
# geolocation_lat                     0
# geolocation_lng                     0
# geolocation_city                   64
# mean_lat                           64
# mean_lng                           64
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Change the date columns' data type to datetime so we can perform date and time operations

# %%
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])
df['order_approved_at'] = pd.to_datetime(df['order_approved_at'])
df['order_delivered_carrier_date'] = pd.to_datetime(df['order_delivered_carrier_date'])
df['order_delivered_customer_date'] = pd.to_datetime(df['order_delivered_customer_date'])
df['order_estimated_delivery_date'] = pd.to_datetime(df['order_estimated_delivery_date'])

# %% [markdown]
# ### Calculate our target feature (shipment_time_in_days). Shipment time is equal to the time between order getting shipped and delivered.

# %%
df['shipment_time_in_days'] =  (df['order_delivered_customer_date'] - df['order_delivered_carrier_date']).dt.days
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 1  40c5e18f7d112b59b3e5113a59a905b3  67407057a7d5ee17d1cd09523f484d13
# 2  86674ccaee19790309333210917b2c7d  1b338293f35549b5e480b9a3d7bbf3cd
# 3  f913d229653fdd809c249ed98ab6b754  e1365d7b227b247b6bc0931771885eaf
# 4  9b85bbefeeacfebc3ff603d20511734f  7f4f07b97783e894fccff9d72e0988b3
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 1    delivered      2018-06-11 10:25:52 2018-06-11 10:58:32
# 2    delivered      2018-08-09 11:37:35 2018-08-09 14:35:19
# 3    delivered      2018-04-30 02:18:32 2018-04-30 03:00:14
# 4    delivered      2017-11-27 10:32:51 2017-11-27 11:14:36
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2018-07-26 14:31:00           2018-08-07 15:27:45
# 1          2018-06-14 13:03:00           2018-06-19 00:31:13
# 2          2018-08-10 14:34:00           2018-08-14 18:51:47
# 3          2018-04-30 13:54:00           2018-05-08 17:53:51
# 4          2017-11-29 15:16:47           2017-12-07 19:48:32
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0                    2018-08-13                   1       boleto
# 1                    2018-07-16                   1  credit_card
# 2                    2018-08-22                   1  credit_card
# 3                    2018-05-24                   1  credit_card
# 4                    2017-12-20                   1  credit_card
#
#    payment_installments  payment_value                customer_unique_id  \
# 0                     1         141.46  af07308b275d755c9edb36a90c618231
# 1                     3         128.68  7cfba6e55439cae3fd2479d62fafe67f
# 2                     5         135.82  8b8028d453a01986b48c4271cc341475
# 3                     4         137.45  66c70ed7726abccfbee61a9a39de15c5
# 4                     3         126.11  293c9db44b6588c4e52fbef455fccde8
#
#    customer_zip_code_prefix   customer_city customer_state  order_item_id  \
# 0                     47813       barreiras             ba              1
# 1                     22240  rio de janeiro             rj              1
# 2                     14500       ituverava             sp              1
# 3                     90050    porto alegre             rs              1
# 4                     88085   florianopolis             sc              1
#
#                          product_id                         seller_id  \
# 0  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 1  595fac2a385ac33a80bd5114aec74eb8  ef0ace09169ac090589d85746e3e036f
# 2  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 3  595fac2a385ac33a80bd5114aec74eb8  ef0ace09169ac090589d85746e3e036f
# 4  595fac2a385ac33a80bd5114aec74eb8  ef0ace09169ac090589d85746e3e036f
#
#    shipping_limit_date  price  freight_value product_category_name  \
# 0  2018-07-30 03:24:27  118.7          22.76            perfumaria
# 1  2018-06-15 10:58:32  119.9           8.78            perfumaria
# 2  2018-08-13 14:31:29  116.9          18.92            perfumaria
# 3  2018-05-07 02:31:13  119.9          17.55            perfumaria
# 4  2017-12-01 11:14:36  109.9          16.21            perfumaria
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 29.0                       178.0                 1.0
# 1                 29.0                       178.0                 1.0
# 2                 29.0                       178.0                 1.0
# 3                 29.0                       178.0                 1.0
# 4                 29.0                       178.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             400.0               19.0               13.0              19.0
# 1             400.0               19.0               13.0              19.0
# 2             400.0               19.0               13.0              19.0
# 3             400.0               19.0               13.0              19.0
# 4             400.0               19.0               13.0              19.0
#
#   product_category_name_english geolocation_state  geolocation_lat  \
# 0                     perfumery                ba       -13.049361
# 1                     perfumery                rj       -22.743477
# 2                     perfumery                sp       -23.155308
# 3                     perfumery                rs       -29.679191
# 4                     perfumery                sc       -27.222486
#
#    geolocation_lng geolocation_city   mean_lat   mean_lng  \
# 0       -39.560649        barreiras -12.148291 -44.967260
# 1       -43.155540   rio de janeiro -22.914910 -43.312883
# 2       -47.084074        ituverava -20.331414 -47.789388
# 3       -52.032652     porto alegre -30.049252 -51.188582
# 4       -49.617937    florianopolis -27.576836 -48.517952
#
#    shipment_time_in_days
# 0                     12
# 1                      4
# 2                      4
# 3                      8
# 4                      8

# %% [markdown]
# ### Keep only a subset of features that we think might be useful in terms of prediction of the shipment time in days

# %%
df = df[[
    'price',
    'freight_value',
    'product_weight_g',
    'product_length_cm',
    'product_height_cm',
    'product_width_cm',
    'mean_lat',
    'mean_lng',
    'shipment_time_in_days'
]]
df.head()
# Out:
#    price  freight_value  product_weight_g  product_length_cm  \
# 0  118.7          22.76             400.0               19.0
# 1  119.9           8.78             400.0               19.0
# 2  116.9          18.92             400.0               19.0
# 3  119.9          17.55             400.0               19.0
# 4  109.9          16.21             400.0               19.0
#
#    product_height_cm  product_width_cm   mean_lat   mean_lng  \
# 0               13.0              19.0 -12.148291 -44.967260
# 1               13.0              19.0 -22.914910 -43.312883
# 2               13.0              19.0 -20.331414 -47.789388
# 3               13.0              19.0 -30.049252 -51.188582
# 4               13.0              19.0 -27.576836 -48.517952
#
#    shipment_time_in_days
# 0                     12
# 1                      4
# 2                      4
# 3                      8
# 4                      8

# %% [markdown]
# ### Some of the features should be greater than zero. If not, remove them.

# %%
df = df[(df['price'] > 0) & 
       (df['freight_value'] > 0) &
       (df['product_weight_g'] > 0) &
       (df['product_length_cm'] > 0) &
       (df['product_height_cm'] > 0) &
       (df['product_width_cm'] > 0)]

# %% [markdown]
# ### We can engineer some new features by using existing ones

# %%
df['order_sum'] = df['price'] + df['freight_value']
df['mean_product_price'] = df['order_sum'] / df['product_weight_g']
df['order_volume'] = df['product_length_cm'] * df['product_height_cm'] * df['product_width_cm']

# %% [markdown]
# ### Plot the correlation heatmap

# %% [markdown]
# #### As seen in the heatmap, there are no strongly correlated features with delivery_time_in_days

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

# %% [markdown]
# ### Seperate input and output columns and create train and test sets

# %%
from sklearn.model_selection import train_test_split

X = df.loc[:, df.columns != 'shipment_time_in_days'].values
y = df.loc[:, df.columns == 'shipment_time_in_days'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=8)

# %% [markdown]
# ### Start modeling with LinearRegression

# %%
from sklearn.linear_model import LinearRegression

linear_regression = LinearRegression()
linear_regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

y_pred = linear_regression.predict(X_test)

print(f'Mean absolute error: {mean_absolute_error(y_pred, y_test)}')
print(f'Mean absolute percentage error: {mean_absolute_percentage_error(y_pred, y_test)}')
# Out:
# Mean absolute error: 5.153912208765013
# Mean absolute percentage error: 0.6243368572335546

# %% [markdown]
# ### Now let's try popular Random Forest algorithm

# %%
from sklearn.ensemble import RandomForestRegressor

random_forest = RandomForestRegressor()
random_forest.fit(X_train, y_train)
# Out:
# c:\users\samet\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# RandomForestRegressor()

# %%
y_pred = random_forest.predict(X_test)

print(f'Mean absolute error: {mean_absolute_error(y_pred, y_test)}')
print(f'Mean absolute percentage error: {mean_absolute_percentage_error(y_pred, y_test)}')
# Out:
# Mean absolute error: 4.174370388285375
# Mean absolute percentage error: 0.5195302364865585

# %% [markdown]
# ### Lastly try XGBoost on our data

# %%
import xgboost

xgb_r = xgboost.XGBRegressor()
xgb_r.fit(X_train, y_train)
# Out:
# XGBRegressor()

# %%
y_pred = xgb_r.predict(X_test)

print(f'Mean absolute error: {mean_absolute_error(y_pred, y_test)}')
print(f'Mean absolute percentage error: {mean_absolute_percentage_error(y_pred, y_test)}')
# Out:
# Mean absolute error: 4.459118116339595
# Mean absolute percentage error: 0.5477282469949901

# %% [markdown]
# ### The best performing model is RandomForestRegressor with the mean absolute percentage error of 51.9%
